# %% [markdown]
# # EDA-1
#
# Q1=> What is the range of selling prices in the dataset?
#
# ans=>Range of selling prices: ₹5,000 to ₹7,60,000
#
#
# Q2=> What is the median selling price for bikes in the dataset?
#
# ans=>Median selling price: ₹45,000
#
#
# Q3=> What is the most common seller type?
#
# ans=>Most common seller type: Individual
#
#
# Q4=> How many bikes have driven more than 50,000 kilometers?
#
# ans=>Bikes driven more than 50,000 km: 170
#
#
# Q5=> What is the average km_driven value for each ownership typeD?
#
# ans=>Average km driven per ownership type:
#
# 1st owner: 32,816 km
#
# 2nd owner: 39,289 km
#
# 3rd owner: 33,292 km
#
# 4th owner: 3,11,500 km (likely an outlier)
# Q6=> What proportion of bikes are from the year 2015 or older?
#
# ans=>Proportion of bikes from 2015 or older: ~56.6%
#
#
# Q7=> What is the trend of missing values across the dataset?
#
# ans=>Missing values: 435 missing values in ex_showroom_price, none in other columns
#
#
# Q8=> What is the highest ex_showroom_price recorded, and for which bike?
#
# ans=>Highest ex-showroom price & bike: Harley-Davidson Street Bob (₹12,78,000)
#
#
# Q9=> What is the total number of bikes listed by each seller type?
#
# ans=>Total bikes listed by seller type:
#
# Individual: 1,055
#
# Dealer: 6
#
#
# Q10=> What is the relationship between selling_price and km_driven for first-owner bikes?
#
# ans=>Relationship between selling price and km_driven for first-owner bikes:
#
# A scatter plot shows that as km_driven increases, selling price generally decreases, though there are some exceptions.
#
#
# Q11=> Identify and remove outliers in the km_driven column using the IQR method?
#
# ans=>Outliers in km_driven removed using IQR method:
#
# 1022 bikes remain after removing extreme values.
#
#
# Q12=> Perform a bivariate analysis to visualize the relationship between year and selling_price?
#
# ans=>Bivariate analysis (year vs. selling price):
#
# Newer bikes generally have higher selling prices, but there are some older high-priced models
#
#
# Q13=> What is the average depreciation in selling price based on the bike's age (current year - manufacturing year)?
#
# ans=>Average depreciation in selling price based on bike age:
#
# Age 5 years: ₹1,83,333
#
# Age 6 years: ₹1,19,689
#
# Age 7 years: ₹87,660
#
# Age 8 years: ₹78,894
#
# Age 9 years: ₹58,469
#
#
# Q14=> Which bike names are priced significantly above the average price for their manufacturing year?
#
# ans=>Bikes priced significantly above average for their year:
#
# Examples:
#
# Royal Enfield Classic 350 (2019): ₹1,75,000
#
# Yamaha YZF R3 (2019): ₹3,65,000
#
# Royal Enfield Bullet 350 (2008): ₹1,80,000
#
#
# Q15=> Develop a correlation matrix for numeric columns and visualize it using a heatmap.
#
# ans=>elling price positively correlates with ex-showroom price (expected).
#
# Weak correlation between km_driven and selling price, indicating other factors influence pricing.

# %% [markdown]
# # EDA-2
#
# Q1=> What is the average selling price of cars for each dealer, and how does it compare across different dealersE
#
# ans=>Average selling price of cars for each dealer
#
# The top 5 dealers with the highest average selling price:
#
# U-Haul CO: $28,769
#
# Classic Chevy: $28,602
#
# Rabun Used Car Sales: $28,527
#
# Iceberg Rentals: $28,522
#
# Enterprise Rent A Car: $28,312
#
#
# Q2=> Which car brand (Company) has the highest variation in prices, and what does this tell us about the pricing
# trendsE
#
# ans=>The top 5 brands with the highest standard deviation in prices:
#
# Lincoln: $19,658
#
# Saab: $19,653
#
# Cadillac: $19,517
#
# Plymouth: $19,065
#
# Lexus: $17,852
#
# This suggests that Lincoln and Saab have a wide range of car prices, indicating varied models from budget to premium
#
#
# Q3=> What is the distribution of car prices for each transmission type, and how do the interquartile ranges
# compareE
#
# ans=>Automatic transmission:
#
# Mean: $28,248, Min: $1,200, Max: $75,700
#
# Manual transmission:
#
# Mean: $27,914, Min: $1,700, Max: $85,800
#
#
# Q4=> What is the distribution of car prices across different regionsE
#
# ans=>Highest average price: Austin ($28,341)
#
# Lowest average price: Janesville ($27,833)
#
#
# Q5=> What is the distribution of cars based on body stylesE
#
# ans=>SUVs are the most common (6,374 cars)
#
# Followed by Hatchbacks (6,128), Sedans (4,488), Passenger Cars (3,945), and Hardtops (2,971)
#
#
# Q6=> How does the average selling price of cars vary by customer gender and annual incomeE
#
# ans=>Female customers: $28,277
#
# Male customers: $28,039
#
#
# Q7=> What is the distribution of car prices by region, and how does the number of cars sold vary by regionE
#
# ans=>Most cars were sold in Austin (4,135 cars)
#
# Followed by Janesville (3,821), Scottsdale (3,433), and Pasco (3,131)
#
#
# Q8=> How does the average car price differ between cars with different engine sizesE
#
# ans=>Average car price difference based on engine size
#
# Double Overhead Camshaft: $28,248
#
# Overhead Camshaft: $27,914
#
#
# Q9=> How do car prices vary based on the customer’s annual income bracketE
#
# ans=>Car prices based on customer’s annual income bracket
#
# Income below $50K: $27,884
#
# Income $50K-$100K: $43,000 (highest)
#
# Income $100K-$500K: $28,563
#
# Income $500K-$1M: $28,011
#
# Income $1M+: $28,186
#
#
# Q10=> What are the top 5 car models with the highest number of sales, and how does their price distribution lookE
#
# ans=>Top 5 car models with the highest number of sales
#
# Diamante (418 units)
#
# Silhouette (411 units)
#
# Prizm (411 units)
#
# Passat (391 units)
#
# Ram Pickup (383 units)
#
#
# Q11=> How does car price vary with engine size across different car colors, and which colors have the highest price
# variationE
#
# ans=>Car price variation based on engine size and car colors
#
# Black cars have higher price variation for both engine types.
#
# Pale White cars with Double Overhead Camshaft engines show the highest price deviation ($14,402).
#
#
# Q12=> Is there any seasonal trend in car sales based on the date of saleE
#
# ans=>Highest sales in December (3,546 cars)
#
# Lowest sales in February (735 cars)
#
#
# Q13=> How does the car price distribution change when considering different combinations of body style and
# transmission typeE
#
# ans=>Car price distribution based on body style and transmission type
#
# Hardtop Automatic cars: Highest average price $31,520
#
# Hatchback Manual cars: Highest standard deviation in price $16,284
#
#
# Q14=> What is the correlation between car price, engine size, and annual income of customers, and how do these
# features interactE
#
# ans=>Correlation between car price, engine size, and annual income
#
# Price and annual income correlation: 0.012 (very weak)
#
# This suggests that car prices do not significantly vary with customer income.
#
#
# Q15=> How does the average car price vary across different car models and engine types?
#
# ans=>Average car price variation across different models and engine types
#
# Most expensive model: 3-Sep with Double Overhead Camshaft ($37,986)
#
# Cheapest model: Xterra with Double Overhead Camshaft ($15,940)

# %% [markdown]
# # EDA-3
#
# Q1=> What is the average rating for each product categoryk
#
# ans=>Top 5 highest-rated categories:
#
# Tablets (4.6)
#
# Networking Devices - PowerLAN Adapters (4.5)
#
# Cameras & Photography Accessories - Film (4.5)
#
# Home Audio - Streaming Clients (4.5)
#
# Office Electronics - Basic Calculators (4.5)
#
#
# Q2=> What are the top rating_count products by categoryk
#
# ans=>Top-rated products by rating count in each category
#
# Most reviewed product: AmazonBasics Flexible Premium HDMI Cable (426,973 reviews)
#
# Top mobile accessory: boAt Bassheads 100 Wired Earphones (363,713 reviews)
#
#
# Q3=> What is the distribution of discounted prices vs. actual pricesk
#
# ans=>Distribution of discounted prices vs. actual prices
#
# Average actual price: $5,444
#
# Average discounted price: $3,125
#
# Maximum actual price: $139,900
#
# Minimum price: $39
#
#
# Q4=> How does the average discount percentage vary across categoriesk
#
# ans=>Highest discount categories (90%+):
#
# Mobile Accessories - Phone Charms
#
# Cable Connection Protectors
#
# Headphone Earpads
#
#
# Q5=> What are the most popular product namesk
#
# ans=Most popular product names (highest rating count)
#
# AmazonBasics Flexible Premium HDMI Cable
#
# Amazon Basics High-Speed HDMI Cable
#
# boAt Bassheads 100 Wired Earphones
#
#
# Q6=> What are the most popular product keywordsk
#
# ans=>Top 10 keywords:
#
# "with" (718 occurrences)
#
# "for" (614)
#
# "USB" (342)
#
# "Cable" (306)
#
# "Charging" (212)
#
# "Fast" (208)
#
#
# Q7=> What are the most popular product reviewsk
#
# ans=>Review for AmazonBasics HDMI Cable: "It's quite good and value for money" (426,973 reviews)
#
# Review for boAt Bassheads 100 Earphones: "Best value for money" (363,713 reviews)
#
#
# Q8=> What is the correlation between discounted_price and ratingk
#
# ans=>Correlation between discounted price and rating
#
# Correlation coefficient: 0.12 (Weak positive correlation)
#
# Insight: Price does not strongly influence ratings
#
#
# Q9=> What are the Top 5 categories based on the highest ratingsk
#
# ans=>op 5 categories based on highest ratings
#
# Tablets, Networking Devices, Cameras & Photography, Home Audio, Office Electronics
#
#
# Q10=> Identify any potential areas for improvement or optimization based on the data analysis
#
# ans=>Missing values: Minor issues in ratings (1 missing value) and rating count (2 missing values)
#
# Low-rated categories (below 3.5 stars):
#
# PC Headsets (3.5)
#
# Keyboard & Mice Accessories - Dust Covers (3.4)
#
# Coffee Grinders - Electric Grinders (3.3)
